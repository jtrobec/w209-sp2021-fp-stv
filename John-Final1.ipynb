# %%
import json
from os import listdir
from os.path import isfile, join
import altair as alt

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load in Data
# * Open all json files that contain traces and append them to a list with all of the traces.
#     - This makes the data ready to use with pandas dataframes and easy to create visualizations with Altair

# %%
baseDirectory = 'data/synthetic/20210302-hipster-shop'
directories = listdir(baseDirectory)

# %%
traces = []
for directory in directories:
    thisDirectory = baseDirectory + '/' + directory
    try:
        with open(thisDirectory) as f:
          data = json.load(f)
    except:
        continue
    traces.append(data)

# %%
traces
# Out:
# [[{'traceId': '550997223f8c4b30',
#    'parentId': '550997223f8c4b30',
#    'id': '1234d6244fad26ab',
#    'name': '/getcart',
#    'timestamp': 1614738754173000,
#    'duration': 190000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '14978',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '550997223f8c4b30',
#    'parentId': '550997223f8c4b30',
#    'id': 'fd6c6a8dad1dac47',
#    'name': '/getrecommendations',
#    'timestamp': 1614738754163000,
#    'duration': 226000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '14979',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '550997223f8c4b30',
#    'parentId': 'fd6c6a8dad1dac47',
#    'id': '3deb074f82f2e50c',
#    'name': '/getproducts',
#    'timestamp': 1614738754350000,
#    'duration': 5000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '14980',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '550997223f8c4b30',
#    'id': '550997223f8c4b30',
#    'name': '/cart',
#    'timestamp': 1614738754094000,
#    'duration': 334000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '14977',
#     'region': 'us-west-1',
#     'version': 'v125'}}],
#  [{'traceId': '592363a229596c88',
#    'id': '592363a229596c88',
#    'name': '/product',
#    'timestamp': 1614740571041000,
#    'duration': 501000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/product',
#     'load_generator.seq_num': '417',
#     'region': 'us-east-1',
#     'starter': 'bulbasaur',
#     'version': 'v125'}},
#   {'traceId': '592363a229596c88',
#    'parentId': '592363a229596c88',
#    'id': '10c4856b83dbbc71',
#    'name': '/adrequest',
#    'timestamp': 1614740571213000,
#    'duration': 232000,
#    'localEndpoint': {'serviceName': 'adservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://adservice/AdRequest',
#     'load_generator.seq_num': '421'}},
#   {'traceId': '592363a229596c88',
#    'parentId': '592363a229596c88',
#    'id': 'b290c3515fad879f',
#    'name': '/getrecommendations',
#    'timestamp': 1614740571079000,
#    'duration': 424000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '419',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '592363a229596c88',
#    'parentId': '592363a229596c88',
#    'id': 'd8eef27c349a9e67',
#    'name': '/getproducts',
#    'timestamp': 1614740571182000,
#    'duration': 96000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '418',
#     'region': 'us-east-1',
#     'starter': 'bulbasaur',
#     'version': 'v53'}},
#   {'traceId': '592363a229596c88',
#    'parentId': 'b290c3515fad879f',
#    'id': '439e9e64c290a7ae',
#    'name': '/getproducts',
#    'timestamp': 1614740571190000,
#    'duration': 169000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '420',
#     'region': 'us-east-1',
#     'version': 'v53'}}],
#  [{'traceId': '110ebb758dcef8a4',
#    'id': '110ebb758dcef8a4',
#    'name': '/cart',
#    'timestamp': 1614738141844000,
#    'duration': 426000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '1828',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '110ebb758dcef8a4',
#    'parentId': '110ebb758dcef8a4',
#    'id': '12bdcd0b032c3698',
#    'name': '/getrecommendations',
#    'timestamp': 1614738141935000,
#    'duration': 306000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '1830',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '110ebb758dcef8a4',
#    'parentId': '110ebb758dcef8a4',
#    'id': '81f1f21d6d21b4af',
#    'name': '/getcart',
#    'timestamp': 1614738141884000,
#    'duration': 161000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '1829',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '110ebb758dcef8a4',
#    'parentId': '12bdcd0b032c3698',
#    'id': '14516d24b5f196a9',
#    'name': '/getproducts',
#    'timestamp': 1614738142026000,
#    'duration': 56000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '1831',
#     'region': 'us-east-1',
#     'version': 'v52'}}],
#  [{'traceId': '17165cd64df27486',
#    'parentId': '73b5c6e8d273f2a9',
#    'id': '1982abc565f8d9a3',
#    'name': '/getproducts',
#    'timestamp': 1614738679709000,
#    'duration': 99000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '13378',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '17165cd64df27486',
#    'parentId': '17165cd64df27486',
#    'id': '73b5c6e8d273f2a9',
#    'name': '/getrecommendations',
#    'timestamp': 1614738679654000,
#    'duration': 253000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '13377',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '17165cd64df27486',
#    'id': '17165cd64df27486',
#    'name': '/cart',
#    'timestamp': 1614738679594000,
#    'duration': 393000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '13375',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '17165cd64df27486',
#    'parentId': '17165cd64df27486',
#    'id': '6393e71192a584ce',
#    'name': '/getcart',
#    'timestamp': 1614738679643000,
#    'duration': 171000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '13376',
#     'region': 'us-east-1',
#     'version': 'v5'}}],
#  [{'traceId': '127823bd98c4caec',
#    'parentId': '127823bd98c4caec',
#    'id': '386951e17136bb16',
#    'name': '/getcart',
#    'timestamp': 1614738523168000,
#    'duration': 131000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '10031',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '127823bd98c4caec',
#    'id': '127823bd98c4caec',
#    'name': '/cart',
#    'timestamp': 1614738523094000,
#    'duration': 388000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '10030',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '127823bd98c4caec',
#    'parentId': '2c2df7ac375569e7',
#    'id': 'ba8dac85455687db',
#    'name': '/getproducts',
#    'timestamp': 1614738523302000,
#    'duration': 1,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '10033',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '127823bd98c4caec',
#    'parentId': '127823bd98c4caec',
#    'id': '2c2df7ac375569e7',
#    'name': '/getrecommendations',
#    'timestamp': 1614738523163000,
#    'duration': 251000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '10032',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '3bc3187f1e5d5f3b',
#    'id': '3bc3187f1e5d5f3b',
#    'name': '/cart',
#    'timestamp': 1614740577791000,
#    'duration': 405000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '567',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': '3bc3187f1e5d5f3b',
#    'parentId': '3bc3187f1e5d5f3b',
#    'id': 'e5606f3cc36aa10c',
#    'name': '/getrecommendations',
#    'timestamp': 1614740577826000,
#    'duration': 344000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '569',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '3bc3187f1e5d5f3b',
#    'parentId': '3bc3187f1e5d5f3b',
#    'id': '865eb086b6313c2b',
#    'name': '/getcart',
#    'timestamp': 1614740577890000,
#    'duration': 27000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '568',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '3bc3187f1e5d5f3b',
#    'parentId': 'e5606f3cc36aa10c',
#    'id': '0d5921eaf02ecc0d',
#    'name': '/getproducts',
#    'timestamp': 1614740578018000,
#    'duration': 5000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '570',
#     'region': 'us-east-1',
#     'version': 'v53'}}],
#  [{'traceId': '51a4f6e112413ab0',
#    'parentId': '51a4f6e112413ab0',
#    'id': 'b76a38b57517144b',
#    'name': '/getcart',
#    'timestamp': 1614738590396000,
#    'duration': 124000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '11477',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '51a4f6e112413ab0',
#    'id': '51a4f6e112413ab0',
#    'name': '/cart',
#    'timestamp': 1614738590344000,
#    'duration': 291000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '11476',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '51a4f6e112413ab0',
#    'parentId': 'cb9ce698402da77f',
#    'id': '006d4bf98b61cbbd',
#    'name': '/getproducts',
#    'timestamp': 1614738590424000,
#    'duration': 4000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '11479',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '51a4f6e112413ab0',
#    'parentId': '51a4f6e112413ab0',
#    'id': 'cb9ce698402da77f',
#    'name': '/getrecommendations',
#    'timestamp': 1614738590350000,
#    'duration': 257000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '11478',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': 'c5654f25c934cef1',
#    'id': 'c5654f25c934cef1',
#    'name': '/cart',
#    'timestamp': 1614738801344000,
#    'duration': 418000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '16003',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': 'c5654f25c934cef1',
#    'parentId': 'c5654f25c934cef1',
#    'id': '56da3ef1a5b3efa8',
#    'name': '/getrecommendations',
#    'timestamp': 1614738801434000,
#    'duration': 307000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '16005',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': 'c5654f25c934cef1',
#    'parentId': '56da3ef1a5b3efa8',
#    'id': 'df3e061b48289e91',
#    'name': '/getproducts',
#    'timestamp': 1614738801619000,
#    'duration': 69000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '16006',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': 'c5654f25c934cef1',
#    'parentId': 'c5654f25c934cef1',
#    'id': '77b1669fa5c6214a',
#    'name': '/getcart',
#    'timestamp': 1614738801358000,
#    'duration': 159000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '16004',
#     'region': 'us-east-1',
#     'version': 'v5'}}],
#  [{'traceId': 'a167f18c5d9b1e4c',
#    'id': 'a167f18c5d9b1e4c',
#    'name': '/cart',
#    'timestamp': 1614738252594000,
#    'duration': 475000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '4208',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': 'a167f18c5d9b1e4c',
#    'parentId': '4809ec342828782f',
#    'id': 'bc8fe593152d0eb4',
#    'name': '/getproducts',
#    'timestamp': 1614738252810000,
#    'duration': 8000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '4211',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': 'a167f18c5d9b1e4c',
#    'parentId': 'a167f18c5d9b1e4c',
#    'id': '7fab23e6d7ec2162',
#    'name': '/getcart',
#    'timestamp': 1614738252618000,
#    'duration': 169000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '4209',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': 'a167f18c5d9b1e4c',
#    'parentId': 'a167f18c5d9b1e4c',
#    'id': '4809ec342828782f',
#    'name': '/getrecommendations',
#    'timestamp': 1614738252693000,
#    'duration': 297000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '4210',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '353d2ea9d0b2e4e4',
#    'id': '353d2ea9d0b2e4e4',
#    'name': '/product',
#    'timestamp': 1614738881593000,
#    'duration': 747000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/product',
#     'load_generator.seq_num': '17716',
#     'region': 'us-west-1',
#     'starter': 'bulbasaur',
#     'version': 'v125'}},
#   {'traceId': '353d2ea9d0b2e4e4',
#    'parentId': '353d2ea9d0b2e4e4',
#    'id': 'e447a43f8f6878b8',
#    'name': '/getproducts',
#    'timestamp': 1614738881657000,
#    'duration': 11000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '17717',
#     'region': 'us-west-1',
#     'starter': 'bulbasaur',
#     'version': 'v52'}},
#   {'traceId': '353d2ea9d0b2e4e4',
#    'parentId': '8120fbb56facc495',
#    'id': 'eff101e193c1cfa2',
#    'name': '/getproducts',
#    'timestamp': 1614738881857000,
#    'duration': 22000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '17719',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '353d2ea9d0b2e4e4',
#    'parentId': '353d2ea9d0b2e4e4',
#    'id': '8120fbb56facc495',
#    'name': '/getrecommendations',
#    'timestamp': 1614738881741000,
#    'duration': 212000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '17718',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '353d2ea9d0b2e4e4',
#    'parentId': '353d2ea9d0b2e4e4',
#    'id': 'be436eda49d07529',
#    'name': '/adrequest',
#    'timestamp': 1614738881716000,
#    'duration': 454000,
#    'localEndpoint': {'serviceName': 'adservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://adservice/AdRequest',
#     'load_generator.seq_num': '17720'}}],
#  [{'traceId': '4c8e8c4549f999fe',
#    'parentId': '4c8e8c4549f999fe',
#    'id': '855226f140eae747',
#    'name': '/getcart',
#    'timestamp': 1614738503865000,
#    'duration': 96000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '9611',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '4c8e8c4549f999fe',
#    'id': '4c8e8c4549f999fe',
#    'name': '/cart',
#    'timestamp': 1614738503844000,
#    'duration': 365000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '9610',
#     'region': 'us-east-1',
#     'version': 'v125'}},
#   {'traceId': '4c8e8c4549f999fe',
#    'parentId': '97f7f427f9c6a8f4',
#    'id': '2ee9ed9e7730386c',
#    'name': '/getproducts',
#    'timestamp': 1614738503945000,
#    'duration': 35000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '9613',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '4c8e8c4549f999fe',
#    'parentId': '4c8e8c4549f999fe',
#    'id': '97f7f427f9c6a8f4',
#    'name': '/getrecommendations',
#    'timestamp': 1614738503879000,
#    'duration': 269000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '9612',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '125fc803f8ba2020',
#    'parentId': '125fc803f8ba2020',
#    'id': '21950def0b517a02',
#    'name': '/getcart',
#    'timestamp': 1614738534672000,
#    'duration': 122000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '10275',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '125fc803f8ba2020',
#    'parentId': '958885b824aff079',
#    'id': '766c61091d264a21',
#    'name': '/getproducts',
#    'timestamp': 1614738534700000,
#    'duration': 93000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '10277',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '125fc803f8ba2020',
#    'id': '125fc803f8ba2020',
#    'name': '/cart',
#    'timestamp': 1614738534594000,
#    'duration': 259000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '10274',
#     'region': 'us-east-1',
#     'version': 'v125'}},
#   {'traceId': '125fc803f8ba2020',
#    'parentId': '125fc803f8ba2020',
#    'id': '958885b824aff079',
#    'name': '/getrecommendations',
#    'timestamp': 1614738534676000,
#    'duration': 139000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '10276',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '2bed366b00c967bd',
#    'id': '2bed366b00c967bd',
#    'name': '/cart',
#    'timestamp': 1614738219594000,
#    'duration': 299000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '3504',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '2bed366b00c967bd',
#    'parentId': '2bed366b00c967bd',
#    'id': '178e54f1061e8ae8',
#    'name': '/getcart',
#    'timestamp': 1614738219678000,
#    'duration': 125000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '3505',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '2bed366b00c967bd',
#    'parentId': '2bed366b00c967bd',
#    'id': '49726fe7738ac9f0',
#    'name': '/getrecommendations',
#    'timestamp': 1614738219646000,
#    'duration': 144000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '3506',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '2bed366b00c967bd',
#    'parentId': '49726fe7738ac9f0',
#    'id': '8ca79bf0e21db40a',
#    'name': '/getproducts',
#    'timestamp': 1614738219691000,
#    'duration': 33000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '3507',
#     'region': 'us-east-1',
#     'version': 'v52'}}],
#  [{'traceId': '3cc3efcd15f7ad46',
#    'parentId': '21cf967194b385bf',
#    'id': '1ea2de79c7e19db8',
#    'name': '/getproducts',
#    'timestamp': 1614738413776000,
#    'duration': 70000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '7673',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '3cc3efcd15f7ad46',
#    'id': '3cc3efcd15f7ad46',
#    'name': '/cart',
#    'timestamp': 1614738413594000,
#    'duration': 397000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '7670',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '3cc3efcd15f7ad46',
#    'parentId': '3cc3efcd15f7ad46',
#    'id': '5c64ef7983a83429',
#    'name': '/getcart',
#    'timestamp': 1614738413612000,
#    'duration': 20000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '7671',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '3cc3efcd15f7ad46',
#    'parentId': '3cc3efcd15f7ad46',
#    'id': '21cf967194b385bf',
#    'name': '/getrecommendations',
#    'timestamp': 1614738413629000,
#    'duration': 271000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '7672',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '0da4cec0cb0dcf26',
#    'parentId': '0da4cec0cb0dcf26',
#    'id': '6cba517e0f08fcc1',
#    'name': '/adrequest',
#    'timestamp': 1614738145536000,
#    'duration': 201000,
#    'localEndpoint': {'serviceName': 'adservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://adservice/AdRequest',
#     'load_generator.seq_num': '1899'}},
#   {'traceId': '0da4cec0cb0dcf26',
#    'id': '0da4cec0cb0dcf26',
#    'name': '/product',
#    'timestamp': 1614738145343000,
#    'duration': 444000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'abandoned-calm-abomasnow': 'YAZjyz3KTXo2Vrd0',
#     'abandoned-calm-abra': '3ObXE217QBRa8tCf',
#     'able-hardy-absol': 'oGHJ5Zt3fTINMR3V',
#     'absolute-adamant-amoonguss': 'kxvX3qOX3mZdpCjA',
#     'absolute-brave-accelgor': 'AYTir9tNIfNaKGkG',
#     'absolute-calm-abomasnow': 'A8Kz3CinGpSxrlsu',
#     'absolute-calm-abra': 'ropEZGWQzLOs64Mn',
#     'absolute-calm-accelgor': 'iGFU4l4anTQ8AgmF',
#     'absolute-calm-aerodactyl': 'TTKl4PuxhUbhhURX',
#     'absolute-calm-alomomola': 'RDNM7pM5mjZPdSIt',
#     'absolute-calm-ariados': 'ivCGcPgZoFOdpV0d',
#     'absolute-impish-accelgor': 'oFd1T5jSx3e2xzkm',
#     'absolute-sassy-accelgor': 'pJqTuVGjguRIIIvR',
#     'absolute-sassy-amoonguss': '5uWqKv4qYrfz4ATd',
#     'absolute-sassy-arcanine': 'ocUvpgAjO63c1kJ7',
#     'absolute-sassy-beldum': 'uIWcbXdiof1HrWuF',
#     'academic-lax-aggron': '3krfYPcNIaaP4sxp',
#     'acceptable-hardy-aipom': 'YxEAHvvsC4IpJZ8L',
#     'acceptable-hardy-arcanine': 'q68KUDarnXaxIeq3',
#     'acclaimed-bold-absol': 'wcyn1xwsEu7WclnC',
#     'acidic-hasty-ambipom': 'kKSXC4ZHqZVssOT3',
#     'acrobatic-careful-aegislash': 'T6bmu5Soy3FtvTIk',
#     'acrobatic-sassy-ariados': 'jvzFMUwZZvedUBPY',
#     'acrobatic-sassy-aurorus': 'K9FkV43mZuDNu5yg',
#     'active-sassy-aegislash': '3cXQtPPEYG5Inbk0',
#     'active-sassy-axew': 'SBo6avqOwK5cn0HC',
#     'actual-lax-anorith': 'wm0GeylvMqYQxzpN',
#     'actual-sassy-ampharos': 'hkEHEPubtlLaSm6w',
#     'actual-sassy-bagon': '3PJoqB0612lyuD4b',
#     'admirable-bashful-ampharos': 'cAdu6ekwR5otmFyy',
#     'admirable-sassy-arcanine': 'FTkyqVqhunlNn1Io',
#     'admirable-sassy-bagon': 'qGOBLbc6vsfiem22',
#     'adorable-gentle-accelgor': 'zFKbLOci9ZGQiC4V',
#     'adored-sassy-accelgor': 'jvzFMUwZZvedUBPY',
#     'adored-sassy-anorith': '5iUR40Mmpy8EVm6T',
#     'advanced-sassy-arcanine': '2mefDqz7krNx5gaU',
#     'adventurous-modest-absol': 'ndyr7M9ngSZ6Z5qu',
#     'adventurous-modest-amoonguss': 'Azz5h26Bg6gE1eNQ',
#     'affectionate-sassy-anorith': 'kx0eWmi5oOEhBMv5',
#     'affectionate-sassy-azumarill': 'JzkJo6Wt7o8TF51Q',
#     'aggressive-sassy-amoonguss': 'zjepfXkrRrpPHQzW',
#     'aggressive-sassy-aron': 'XLVQRpEjZFICVwMi',
#     'aggressive-sassy-aurorus': 'kJaBgWSYS4GlakvV',
#     'aggressive-sassy-barboach': 'jySxWuvVzKRvR89H',
#     'agreeable-sassy-ambipom': '4gJjSWGP7BRRzTaI',
#     'alert-sassy-archeops': 'KugBNz07eutoLDNG',
#     'ample-sassy-beautifly': 'VC7E63OC3lBbqhS3',
#     'angelic-sassy-arcanine': 'giBiywKTAbaP4tBj',
#     'http.method': 'GET',
#     'http.url': 'http://frontend/product',
#     'load_generator.seq_num': '1894',
#     'region': 'us-east-1',
#     'starter': 'charmander',
#     'version': 'v125'}},
#   {'traceId': '0da4cec0cb0dcf26',
#    'parentId': '0da4cec0cb0dcf26',
#    'id': 'cd229eb79f5c848e',
#    'name': '/getproducts',
#    'timestamp': 1614738145518000,
#    'duration': 32000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '1895',
#     'region': 'us-east-1',
#     'starter': 'charmander',
#     'version': 'v52'}},
#   {'traceId': '0da4cec0cb0dcf26',
#    'parentId': '2181dce301b30bf4',
#    'id': '8837bd0f9bc2f34e',
#    'name': '/getproducts',
#    'timestamp': 1614738145547000,
#    'duration': 56000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '1897',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '0da4cec0cb0dcf26',
#    'parentId': '0da4cec0cb0dcf26',
#    'id': '2181dce301b30bf4',
#    'name': '/getrecommendations',
#    'timestamp': 1614738145527000,
#    'duration': 165000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '1896',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': 'a63d09f4666d280b',
#    'id': 'a63d09f4666d280b',
#    'name': '/cart',
#    'timestamp': 1614738096344000,
#    'duration': 324000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '845',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': 'a63d09f4666d280b',
#    'parentId': 'a63d09f4666d280b',
#    'id': 'b5bfb74af5ca47e2',
#    'name': '/getcart',
#    'timestamp': 1614738096369000,
#    'duration': 166000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '846',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': 'a63d09f4666d280b',
#    'parentId': 'a63d09f4666d280b',
#    'id': '3481cdacd87e95e3',
#    'name': '/getrecommendations',
#    'timestamp': 1614738096361000,
#    'duration': 268000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '847',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': 'a63d09f4666d280b',
#    'parentId': '3481cdacd87e95e3',
#    'id': 'eb60e70ed0812ae3',
#    'name': '/getproducts',
#    'timestamp': 1614738096511000,
#    'duration': 80000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '848',
#     'region': 'us-east-1',
#     'version': 'v52'}}],
#  [{'traceId': '177a6b6667c74e2a',
#    'parentId': '177a6b6667c74e2a',
#    'id': 'ce1145a58be4fe28',
#    'name': '/adrequest',
#    'timestamp': 1614738222940000,
#    'duration': 254000,
#    'localEndpoint': {'serviceName': 'adservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://adservice/AdRequest',
#     'load_generator.seq_num': '3573'}},
#   {'traceId': '177a6b6667c74e2a',
#    'id': '177a6b6667c74e2a',
#    'name': '/product',
#    'timestamp': 1614738222843000,
#    'duration': 551000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/product',
#     'load_generator.seq_num': '3569',
#     'region': 'us-east-1',
#     'starter': 'squirtle',
#     'version': 'v127'}},
#   {'traceId': '177a6b6667c74e2a',
#    'parentId': '177a6b6667c74e2a',
#    'id': '88f08df1641738b0',
#    'name': '/getproducts',
#    'timestamp': 1614738222897000,
#    'duration': 23000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '3570',
#     'region': 'us-east-1',
#     'starter': 'squirtle',
#     'version': 'v52'}},
#   {'traceId': '177a6b6667c74e2a',
#    'parentId': 'a08c37aba84a38e7',
#    'id': 'fc9a0c785f51720c',
#    'name': '/getproducts',
#    'timestamp': 1614738223093000,
#    'duration': 92000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '3572',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '177a6b6667c74e2a',
#    'parentId': '177a6b6667c74e2a',
#    'id': 'a08c37aba84a38e7',
#    'name': '/getrecommendations',
#    'timestamp': 1614738223006000,
#    'duration': 321000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '3571',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': 'fa850a63570f6e3b',
#    'parentId': 'fa850a63570f6e3b',
#    'id': 'f8eaf015bedfd26b',
#    'name': '/getcart',
#    'timestamp': 1614738713351000,
#    'duration': 159000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '14096',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': 'fa850a63570f6e3b',
#    'parentId': 'fa850a63570f6e3b',
#    'id': '8119bea20bceee74',
#    'name': '/getrecommendations',
#    'timestamp': 1614738713391000,
#    'duration': 129000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '14097',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': 'fa850a63570f6e3b',
#    'parentId': '8119bea20bceee74',
#    'id': '543c2e6adcb769f0',
#    'name': '/getproducts',
#    'timestamp': 1614738713507000,
#    'duration': 1000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '14098',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': 'fa850a63570f6e3b',
#    'id': 'fa850a63570f6e3b',
#    'name': '/cart',
#    'timestamp': 1614738713344000,
#    'duration': 202000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '14095',
#     'region': 'us-west-1',
#     'version': 'v125'}}],
#  [{'traceId': '5cddefc5e26d6bd1',
#    'id': '5cddefc5e26d6bd1',
#    'name': '/shipping',
#    'timestamp': 1614738657844000,
#    'duration': 385000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/shipping',
#     'load_generator.seq_num': '12907',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '5cddefc5e26d6bd1',
#    'parentId': '0653be95e289d22a',
#    'id': '41c2f4cca7bbc328',
#    'name': '/address',
#    'timestamp': 1614738657989000,
#    'duration': 39000,
#    'localEndpoint': {'serviceName': 'shippingservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://shippingservice/Address',
#     'load_generator.seq_num': '12909',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': '5cddefc5e26d6bd1',
#    'parentId': '5cddefc5e26d6bd1',
#    'id': '0653be95e289d22a',
#    'name': '/getquote',
#    'timestamp': 1614738657864000,
#    'duration': 341000,
#    'localEndpoint': {'serviceName': 'shippingservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://shippingservice/GetQuote',
#     'load_generator.seq_num': '12908',
#     'region': 'us-east-1',
#     'version': 'v127'}}],
#  [{'traceId': '49fb26e90f6ad7bb',
#    'parentId': '49fb26e90f6ad7bb',
#    'id': '8f8c7ca73f370e78',
#    'name': '/getrecommendations',
#    'timestamp': 1614738326892000,
#    'duration': 399000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '5809',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '49fb26e90f6ad7bb',
#    'parentId': '49fb26e90f6ad7bb',
#    'id': '7ddd3327ffb09b1b',
#    'name': '/getcart',
#    'timestamp': 1614738326896000,
#    'duration': 164000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '5808',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '49fb26e90f6ad7bb',
#    'parentId': '8f8c7ca73f370e78',
#    'id': 'fb4b9b50a00062a1',
#    'name': '/getproducts',
#    'timestamp': 1614738327044000,
#    'duration': 59000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '5810',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '49fb26e90f6ad7bb',
#    'id': '49fb26e90f6ad7bb',
#    'name': '/cart',
#    'timestamp': 1614738326844000,
#    'duration': 469000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '5807',
#     'region': 'us-east-1',
#     'version': 'v125'}}],
#  [{'traceId': '3e5c6320308492f6',
#    'parentId': '3e5c6320308492f6',
#    'id': 'c955339a6ee16937',
#    'name': '/getcart',
#    'timestamp': 1614738839631000,
#    'duration': 164000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '16822',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '3e5c6320308492f6',
#    'parentId': '3e5c6320308492f6',
#    'id': '0bcca9557601dc11',
#    'name': '/getrecommendations',
#    'timestamp': 1614738839637000,
#    'duration': 322000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '16823',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '3e5c6320308492f6',
#    'parentId': '0bcca9557601dc11',
#    'id': 'e285db5400986319',
#    'name': '/getproducts',
#    'timestamp': 1614738839777000,
#    'duration': 55000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '16824',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '3e5c6320308492f6',
#    'id': '3e5c6320308492f6',
#    'name': '/cart',
#    'timestamp': 1614738839594000,
#    'duration': 405000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '16821',
#     'region': 'us-west-1',
#     'version': 'v125'}}],
#  [{'traceId': 'a4300d288a090902',
#    'id': 'a4300d288a090902',
#    'name': '/cart',
#    'timestamp': 1614738173594000,
#    'duration': 298000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '2514',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': 'a4300d288a090902',
#    'parentId': 'a4300d288a090902',
#    'id': '77d343631d56b0e0',
#    'name': '/getcart',
#    'timestamp': 1614738173675000,
#    'duration': 88000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '2515',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': 'a4300d288a090902',
#    'parentId': 'a4300d288a090902',
#    'id': 'b4ca8962caf05f35',
#    'name': '/getrecommendations',
#    'timestamp': 1614738173652000,
#    'duration': 178000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '2516',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': 'a4300d288a090902',
#    'parentId': 'b4ca8962caf05f35',
#    'id': '35d45eed5ba79e97',
#    'name': '/getproducts',
#    'timestamp': 1614738173740000,
#    'duration': 62000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '2517',
#     'region': 'us-east-1',
#     'version': 'v52'}}],
#  [{'traceId': '9369a655cd09f25f',
#    'id': '9369a655cd09f25f',
#    'name': '/shipping',
#    'timestamp': 1614738477844000,
#    'duration': 448000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/shipping',
#     'load_generator.seq_num': '9054',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': '9369a655cd09f25f',
#    'parentId': 'cdd5f07ba4e4ec22',
#    'id': '66efd2e9e21ac6ff',
#    'name': '/address',
#    'timestamp': 1614738477911000,
#    'duration': 92000,
#    'localEndpoint': {'serviceName': 'shippingservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://shippingservice/Address',
#     'load_generator.seq_num': '9056',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': '9369a655cd09f25f',
#    'parentId': '9369a655cd09f25f',
#    'id': 'cdd5f07ba4e4ec22',
#    'name': '/getquote',
#    'timestamp': 1614738477858000,
#    'duration': 392000,
#    'localEndpoint': {'serviceName': 'shippingservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://shippingservice/GetQuote',
#     'load_generator.seq_num': '9055',
#     'region': 'us-east-1',
#     'version': 'v127'}}],
#  [{'traceId': 'bb17b4da41df7b75',
#    'id': 'bb17b4da41df7b75',
#    'name': '/cart',
#    'timestamp': 1614740598041000,
#    'duration': 434000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '1010',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': 'bb17b4da41df7b75',
#    'parentId': 'bb17b4da41df7b75',
#    'id': '2d54dec01a9f0231',
#    'name': '/getcart',
#    'timestamp': 1614740598140000,
#    'duration': 130000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '1011',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': 'bb17b4da41df7b75',
#    'parentId': 'bb17b4da41df7b75',
#    'id': '96cf268603fc9852',
#    'name': '/getrecommendations',
#    'timestamp': 1614740598093000,
#    'duration': 363000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '1012',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': 'bb17b4da41df7b75',
#    'parentId': '96cf268603fc9852',
#    'id': 'd0fccc6f26ee2b4c',
#    'name': '/getproducts',
#    'timestamp': 1614740598170000,
#    'duration': 95000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '1013',
#     'region': 'us-east-1',
#     'version': 'v53'}}],
#  [{'traceId': '688541eb5755fa16',
#    'id': '688541eb5755fa16',
#    'name': '/cart',
#    'timestamp': 1614738574344000,
#    'duration': 544000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '11129',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '688541eb5755fa16',
#    'parentId': '688541eb5755fa16',
#    'id': 'b97289e7b4bb5b9f',
#    'name': '/getcart',
#    'timestamp': 1614738574369000,
#    'duration': 123000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '11130',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '688541eb5755fa16',
#    'parentId': '27e7a184cef0ae3c',
#    'id': '393d53155e09437b',
#    'name': '/getproducts',
#    'timestamp': 1614738574595000,
#    'duration': 19000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '11132',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '688541eb5755fa16',
#    'parentId': '688541eb5755fa16',
#    'id': '27e7a184cef0ae3c',
#    'name': '/getrecommendations',
#    'timestamp': 1614738574437000,
#    'duration': 368000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '11131',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '094d19df8a03131d',
#    'id': '094d19df8a03131d',
#    'name': '/cart',
#    'timestamp': 1614740599792000,
#    'duration': 433000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '1048',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '094d19df8a03131d',
#    'parentId': '094d19df8a03131d',
#    'id': '9208a69e24fc7bbe',
#    'name': '/getcart',
#    'timestamp': 1614740599872000,
#    'duration': 27000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '1049',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '094d19df8a03131d',
#    'parentId': '98f8b605334df6a2',
#    'id': '300e37fb75aa8e55',
#    'name': '/getproducts',
#    'timestamp': 1614740599916000,
#    'duration': 134000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '1051',
#     'region': 'us-east-1',
#     'version': 'v53'}},
#   {'traceId': '094d19df8a03131d',
#    'parentId': '094d19df8a03131d',
#    'id': '98f8b605334df6a2',
#    'name': '/getrecommendations',
# ...
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': '60f44a068f78b08c',
#    'parentId': '60f44a068f78b08c',
#    'id': 'dc36f52455356c60',
#    'name': '/getrecommendations',
#    'timestamp': 1614738537125000,
#    'duration': 255000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '10326',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '1e0a8fbbbb5806e4',
#    'parentId': '1e0a8fbbbb5806e4',
#    'id': 'b72623ee55c932ff',
#    'name': '/adrequest',
#    'timestamp': 1614738190434000,
#    'duration': 110000,
#    'localEndpoint': {'serviceName': 'adservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://adservice/AdRequest',
#     'load_generator.seq_num': '2877'}},
#   {'traceId': '1e0a8fbbbb5806e4',
#    'id': '1e0a8fbbbb5806e4',
#    'name': '/product',
#    'timestamp': 1614738190343000,
#    'duration': 306000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'abandoned-calm-abomasnow': 'ZHOnGIfnZRPdX16C',
#     'abandoned-calm-abra': 'uCv3FonXXsbs5P9O',
#     'able-hardy-absol': 'rIUHJlEPB9HB9PDn',
#     'absolute-adamant-amoonguss': 'ziNFiBPrXhfgx1oq',
#     'absolute-brave-accelgor': 'oza0Rg27YEhseBsY',
#     'absolute-calm-abomasnow': 'YtTbY0NYtSLdRZTh',
#     'absolute-calm-abra': 'ocwdXxrMMrcRXap1',
#     'absolute-calm-accelgor': 'dEqe8LTVGeic11mp',
#     'absolute-calm-aerodactyl': 'bpJisNsPioBMWeiV',
#     'absolute-calm-alomomola': 'XsfuW2AQHVXCfS73',
#     'absolute-calm-ariados': 'McHNLzqFBVYMb0KL',
#     'absolute-impish-accelgor': 'ZebGsoxxXjjQbG9D',
#     'absolute-sassy-accelgor': 'u7mBvzwHohV2tvA0',
#     'absolute-sassy-amoonguss': '7pUalPQzpVFkJgXQ',
#     'absolute-sassy-arcanine': 'GvMgrcrhXztSIpQF',
#     'absolute-sassy-beldum': 'uPTw94URkVNVUvJR',
#     'academic-lax-aggron': 'WnyE7T0Mt8hQwhHE',
#     'acceptable-hardy-aipom': '72ho0wcTJXkoDjJ5',
#     'acceptable-hardy-arcanine': 'EN5je4ydiLogKWsC',
#     'acclaimed-bold-absol': 'P42H9rQ1EFjI9hpg',
#     'acidic-hasty-ambipom': 'ILTYIuVHEH8qFajC',
#     'acrobatic-careful-aegislash': 'kx0eWmi5oOEhBMv5',
#     'acrobatic-sassy-ariados': 'xJOBwkVUI196L60z',
#     'acrobatic-sassy-aurorus': 'cj9yCzF5OAuKsznL',
#     'active-sassy-aegislash': '3QqtNeWxischBFoe',
#     'active-sassy-axew': 'lfjXZJrtEpTJAcYH',
#     'actual-lax-anorith': 'h6v5eor5RyHWzdP8',
#     'actual-sassy-ampharos': 'RmEuSRKHL6986vwa',
#     'actual-sassy-bagon': 'Ry8N4hc48ytT1BD3',
#     'admirable-bashful-ampharos': 'dA9v5aVXmfZKZzU3',
#     'admirable-sassy-arcanine': 'IXEP5iebptUVmq6A',
#     'admirable-sassy-bagon': 'FuyusXJMuhZAfn2h',
#     'adorable-gentle-accelgor': 'ohpY5QX6JQeuNFWy',
#     'adored-sassy-accelgor': 'qqRCQZjfmcQTOfxQ',
#     'adored-sassy-anorith': 'QUSGcWxVzUj3y1uG',
#     'advanced-sassy-arcanine': 'lE2ta3OJX8edyBTz',
#     'adventurous-modest-absol': 'HWgRL9ygPgHJl6Vo',
#     'adventurous-modest-amoonguss': 'QrhpNzFY7L2hfGKT',
#     'affectionate-sassy-anorith': 'tLv1UXWKHGB7m4hA',
#     'affectionate-sassy-azumarill': 'nHYl9OQI3LGZKdGb',
#     'aggressive-sassy-amoonguss': '69eQ39rJhXOPZKnG',
#     'aggressive-sassy-aron': 'fc9Jt8e6qbuNz0Fa',
#     'aggressive-sassy-aurorus': 'I2H7OZabTNYfWlYV',
#     'aggressive-sassy-barboach': '7qrBwQ47qAI5O3w5',
#     'agreeable-sassy-ambipom': 'JEHSGuD1s50opIme',
#     'alert-sassy-archeops': 'EOsfc0xAvoG7xVN6',
#     'ample-sassy-beautifly': 'IXiSz6zuOQoCvMnB',
#     'angelic-sassy-arcanine': 'Eo7OtJsqaukQnwuE',
#     'http.method': 'GET',
#     'http.url': 'http://frontend/product',
#     'load_generator.seq_num': '2873',
#     'region': 'us-west-1',
#     'starter': 'charmander',
#     'version': 'v125'}},
#   {'traceId': '1e0a8fbbbb5806e4',
#    'parentId': '1e0a8fbbbb5806e4',
#    'id': 'ff45044fed254a4f',
#    'name': '/getrecommendations',
#    'timestamp': 1614738190351000,
#    'duration': 156000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '2875',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '1e0a8fbbbb5806e4',
#    'parentId': '1e0a8fbbbb5806e4',
#    'id': '4d686a27f14a82cf',
#    'name': '/getproducts',
#    'timestamp': 1614738190409000,
#    'duration': 9000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '2874',
#     'region': 'us-west-1',
#     'starter': 'charmander',
#     'version': 'v52'}},
#   {'traceId': '1e0a8fbbbb5806e4',
#    'parentId': 'ff45044fed254a4f',
#    'id': '0ff00b4e69d9b697',
#    'name': '/getproducts',
#    'timestamp': 1614738190416000,
#    'duration': 58000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '2876',
#     'region': 'us-east-1',
#     'version': 'v52'}}],
#  [{'traceId': '314f30820bb97f58',
#    'parentId': '1d8ab97c2d0499b7',
#    'id': 'ecf5fe3927105af5',
#    'name': '/getproducts',
#    'timestamp': 1614738387475000,
#    'duration': 99000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '7118',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '314f30820bb97f58',
#    'parentId': '314f30820bb97f58',
#    'id': '50a5ba3691feb5d7',
#    'name': '/getcart',
#    'timestamp': 1614738387366000,
#    'duration': 120000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '7116',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '314f30820bb97f58',
#    'id': '314f30820bb97f58',
#    'name': '/cart',
#    'timestamp': 1614738387344000,
#    'duration': 371000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '7115',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '314f30820bb97f58',
#    'parentId': '314f30820bb97f58',
#    'id': '1d8ab97c2d0499b7',
#    'name': '/getrecommendations',
#    'timestamp': 1614738387345000,
#    'duration': 327000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '7117',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': 'c660f1d3a1f1a2ce',
#    'parentId': 'c660f1d3a1f1a2ce',
#    'id': '4b7cb0256be23afc',
#    'name': '/getcart',
#    'timestamp': 1614738319639000,
#    'duration': 196000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '5657',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': 'c660f1d3a1f1a2ce',
#    'id': 'c660f1d3a1f1a2ce',
#    'name': '/cart',
#    'timestamp': 1614738319594000,
#    'duration': 464000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '5656',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': 'c660f1d3a1f1a2ce',
#    'parentId': 'c660f1d3a1f1a2ce',
#    'id': '6794ed45c9ac2d25',
#    'name': '/getrecommendations',
#    'timestamp': 1614738319667000,
#    'duration': 303000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '5658',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': 'c660f1d3a1f1a2ce',
#    'parentId': '6794ed45c9ac2d25',
#    'id': '23d1cc24ae61ed4e',
#    'name': '/getproducts',
#    'timestamp': 1614738319848000,
#    'duration': 19000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '5659',
#     'region': 'us-east-1',
#     'version': 'v52'}}],
#  [{'traceId': '0d12c7f7fd20b671',
#    'id': '0d12c7f7fd20b671',
#    'name': '/cart',
#    'timestamp': 1614738084844000,
#    'duration': 402000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '590',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': '0d12c7f7fd20b671',
#    'parentId': '0d12c7f7fd20b671',
#    'id': '5df622fdcd6e5ed9',
#    'name': '/getcart',
#    'timestamp': 1614738084898000,
#    'duration': 74000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '591',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '0d12c7f7fd20b671',
#    'parentId': '0d12c7f7fd20b671',
#    'id': 'd372fe1acefe56ca',
#    'name': '/getrecommendations',
#    'timestamp': 1614738084872000,
#    'duration': 301000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '592',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '0d12c7f7fd20b671',
#    'parentId': 'd372fe1acefe56ca',
#    'id': '21b22b5a9920a7f7',
#    'name': '/getproducts',
#    'timestamp': 1614738084959000,
#    'duration': 65000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '593',
#     'region': 'us-east-1',
#     'version': 'v52'}}],
#  [{'traceId': '07ad6c45e9047f93',
#    'parentId': 'a057d39242bb3692',
#    'id': '6073e184fe0dc300',
#    'name': '/getproducts',
#    'timestamp': 1614738418986000,
#    'duration': 28000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '7785',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '07ad6c45e9047f93',
#    'parentId': '07ad6c45e9047f93',
#    'id': '32fcf78397221b98',
#    'name': '/getcart',
#    'timestamp': 1614738418875000,
#    'duration': 185000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '7783',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '07ad6c45e9047f93',
#    'id': '07ad6c45e9047f93',
#    'name': '/cart',
#    'timestamp': 1614738418844000,
#    'duration': 414000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '7782',
#     'region': 'us-east-1',
#     'version': 'v127'}},
#   {'traceId': '07ad6c45e9047f93',
#    'parentId': '07ad6c45e9047f93',
#    'id': 'a057d39242bb3692',
#    'name': '/getrecommendations',
#    'timestamp': 1614738418920000,
#    'duration': 290000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '7784',
#     'region': 'us-east-1',
#     'version': 'v234'}}],
#  [{'traceId': '2301a9e4245a75e6',
#    'id': '2301a9e4245a75e6',
#    'name': '/cart',
#    'timestamp': 1614740561041000,
#    'duration': 237000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/cart',
#     'load_generator.seq_num': '204',
#     'region': 'us-west-1',
#     'version': 'v125'}},
#   {'traceId': '2301a9e4245a75e6',
#    'parentId': '2301a9e4245a75e6',
#    'id': '77b5474cc198569f',
#    'name': '/getcart',
#    'timestamp': 1614740561090000,
#    'duration': 160000,
#    'localEndpoint': {'serviceName': 'cartservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://cartservice/GetCart',
#     'load_generator.seq_num': '206',
#     'region': 'us-east-1',
#     'version': 'v5'}},
#   {'traceId': '2301a9e4245a75e6',
#    'parentId': '2301a9e4245a75e6',
#    'id': '6ac253a70022da64',
#    'name': '/getrecommendations',
#    'timestamp': 1614740561088000,
#    'duration': 131000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '208',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '2301a9e4245a75e6',
#    'parentId': '6ac253a70022da64',
#    'id': '30decbbe77681995',
#    'name': '/getproducts',
#    'timestamp': 1614740561093000,
#    'duration': 43000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '210',
#     'region': 'us-east-1',
#     'version': 'v53'}}],
#  [{'traceId': '5e6f953853945414',
#    'id': '5e6f953853945414',
#    'name': '/product',
#    'timestamp': 1614738587843000,
#    'duration': 504000,
#    'localEndpoint': {'serviceName': 'frontend', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://frontend/product',
#     'load_generator.seq_num': '11421',
#     'region': 'us-west-1',
#     'starter': 'squirtle',
#     'version': 'v125'}},
#   {'traceId': '5e6f953853945414',
#    'parentId': '5e6f953853945414',
#    'id': 'd0ab8bea2109d2e8',
#    'name': '/getproducts',
#    'timestamp': 1614738587844000,
#    'duration': 37000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '11422',
#     'region': 'us-west-1',
#     'starter': 'squirtle',
#     'version': 'v52'}},
#   {'traceId': '5e6f953853945414',
#    'parentId': '8e0e0f686fa42c2a',
#    'id': '4ef2b6e8f8098e98',
#    'name': '/getproducts',
#    'timestamp': 1614738588081000,
#    'duration': 99000,
#    'localEndpoint': {'serviceName': 'productcatalogservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://productcatalogservice/GetProducts',
#     'load_generator.seq_num': '11424',
#     'region': 'us-east-1',
#     'version': 'v52'}},
#   {'traceId': '5e6f953853945414',
#    'parentId': '5e6f953853945414',
#    'id': '8e0e0f686fa42c2a',
#    'name': '/getrecommendations',
#    'timestamp': 1614738587948000,
#    'duration': 236000,
#    'localEndpoint': {'serviceName': 'recommendationservice',
#     'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://recommendationservice/GetRecommendations',
#     'load_generator.seq_num': '11423',
#     'region': 'us-east-1',
#     'version': 'v234'}},
#   {'traceId': '5e6f953853945414',
#    'parentId': '5e6f953853945414',
#    'id': '695bdd8b781538ff',
#    'name': '/adrequest',
#    'timestamp': 1614738588038000,
#    'duration': 156000,
#    'localEndpoint': {'serviceName': 'adservice', 'ipv4': '192.168.1.180'},
#    'tags': {'http.method': 'GET',
#     'http.url': 'http://adservice/AdRequest',
#     'load_generator.seq_num': '11425'}}],
#  ...]

# %%
names = []
durations = []
traceIDs = []
parentIDs = []
ids = []
traceErrors = []
for trace in traces:
    
    for element in trace:
        traceIDs.append(element['traceId'])
        ids.append(element['id'])
        try:
            parentIDs.append(element['parentId'])
        except:
            parentIDs.append('Na')
        try:
            traceErrors.append(element['tags']['error'])
        except:
            traceErrors.append('false')
            
        names.append(element['name'])
        durations.append(element['duration'])

# %%
traceDf = pd.DataFrame({'Resource Name' : names, 'Duration':durations, 'Trace_ID': traceIDs, 'ID': ids, 'Parent_ID': parentIDs, 'Error?':traceErrors})
traceDf
# Out:
#              Resource Name  Duration          Trace_ID                ID  \
# 0                 /getcart    190000  550997223f8c4b30  1234d6244fad26ab
# 1      /getrecommendations    226000  550997223f8c4b30  fd6c6a8dad1dac47
# 2             /getproducts      5000  550997223f8c4b30  3deb074f82f2e50c
# 3                    /cart    334000  550997223f8c4b30  550997223f8c4b30
# 4                 /product    501000  592363a229596c88  592363a229596c88
# ...                    ...       ...               ...               ...
# 19558                /cart    397000  529885a8ac3c2592  529885a8ac3c2592
# 19559                /cart    485000  b9ae10ad77e3ecee  b9ae10ad77e3ecee
# 19560         /getproducts     95000  b9ae10ad77e3ecee  a2f5e2941ecb468e
# 19561             /getcart     94000  b9ae10ad77e3ecee  5bb0e7a04dd86297
# 19562  /getrecommendations    433000  b9ae10ad77e3ecee  449069260f276449
#
#               Parent_ID Error?
# 0      550997223f8c4b30  false
# 1      550997223f8c4b30  false
# 2      fd6c6a8dad1dac47  false
# 3                    Na  false
# 4                    Na  false
# ...                 ...    ...
# 19558                Na  false
# 19559                Na  false
# 19560  449069260f276449  false
# 19561  b9ae10ad77e3ecee  false
# 19562  b9ae10ad77e3ecee  false
#
# [19563 rows x 6 columns]

# %%
traceDf
# Out:
#              Resource Name  Duration          Trace_ID                ID  \
# 0                 /getcart    190000  550997223f8c4b30  1234d6244fad26ab
# 1      /getrecommendations    226000  550997223f8c4b30  fd6c6a8dad1dac47
# 2             /getproducts      5000  550997223f8c4b30  3deb074f82f2e50c
# 3                    /cart    334000  550997223f8c4b30  550997223f8c4b30
# 4                 /product    501000  592363a229596c88  592363a229596c88
# ...                    ...       ...               ...               ...
# 19558                /cart    397000  529885a8ac3c2592  529885a8ac3c2592
# 19559                /cart    485000  b9ae10ad77e3ecee  b9ae10ad77e3ecee
# 19560         /getproducts     95000  b9ae10ad77e3ecee  a2f5e2941ecb468e
# 19561             /getcart     94000  b9ae10ad77e3ecee  5bb0e7a04dd86297
# 19562  /getrecommendations    433000  b9ae10ad77e3ecee  449069260f276449
#
#               Parent_ID Error?
# 0      550997223f8c4b30  false
# 1      550997223f8c4b30  false
# 2      fd6c6a8dad1dac47  false
# 3                    Na  false
# 4                    Na  false
# ...                 ...    ...
# 19558                Na  false
# 19559                Na  false
# 19560  449069260f276449  false
# 19561  b9ae10ad77e3ecee  false
# 19562  b9ae10ad77e3ecee  false
#
# [19563 rows x 6 columns]

# %%
traceSum = 0 
currTraceID = ''
duration_starts = []
duration_ends = []
duration_start = 0
duration_end = 0
for i in range(len(traceDf)):
    val = traceDf.iloc[i]
    if val['Trace_ID'] != currTraceID:
        duration_start = 0
        currTraceID = val['Trace_ID']
    else:
        duration_start = duration_end
    duration_end = duration_start +  val['Duration']
    duration_starts.append(duration_start)
    duration_ends.append(duration_end)

# %%
traceDf['duration_start'] = duration_starts
traceDf['duration_end'] = duration_ends
traceDf['Data Transfered'] = [round(np.random.uniform(4,10000),1) for i in range(len(traceDf))]
traceDf.head(2)
# Out:
#          Resource Name  Duration          Trace_ID                ID  \
# 0             /getcart    190000  550997223f8c4b30  1234d6244fad26ab
# 1  /getrecommendations    226000  550997223f8c4b30  fd6c6a8dad1dac47
#
#           Parent_ID Error?  duration_start  duration_end  Data Transfered
# 0  550997223f8c4b30  false               0        190000           6217.3
# 1  550997223f8c4b30  false          190000        416000           3230.7

# %%
updatedTraces = pd.DataFrame()
for traceID in set(traceDf['Trace_ID']):
#     print(traceID)
    tes = traceDf[traceDf['Trace_ID'] == traceID]
    root = list(tes['Trace_ID'])[0]
    tes['order'] = [100 for x in range(len(tes))]
    tes['loc start'] = [100 for x in range(len(tes))]
    tes['loc end'] = [100 for x in range(len(tes))]

    tes
    order = []
    root = list(tes['Trace_ID'])[0]
    startLoc = 0
    order = 0
    for i in range(len(tes)):
        t = tes.iloc[i]
        if t['ID'] == root:
            t['order'] = order
            t['loc start'] = startLoc
            t['loc end'] = t['loc start'] + t['Duration']
            tes.iloc[i] = t
    c = 0
    currentRoot = root
    startLoc += 100000
    lastRoot = root
    lastRoots = []
    while c < len(tes) - 1:
        startLoc = tes[tes['ID'] == currentRoot]['loc start'] + 100000
        order = tes[tes['ID'] == currentRoot]['order']
        for i in range(len(tes)):
            t = tes.iloc[i]

            if t['Parent_ID'] == currentRoot:

                t['order'] = order + .5
                order = order + 1
                t['loc start'] = startLoc
                t['loc end'] = t['loc start'] + t['Duration']
                tes.iloc[i] = t
                lastRoots.append(t['ID'])
                c += 1
    #     order = order + 1
        currentRoot = lastRoots.pop(0)
#     print('done')
    updatedTraces = updatedTraces.append(tes)

# %%
traceDf = updatedTraces

# %%
# def plotTrace(traceID):
#     source = traceDf[traceDf['Trace_ID'] == traceID]
#     bars = alt.Chart(source, title='Trace: ' + traceID).mark_bar().encode(
#         y=alt.Y('Resource Name', type='nominal', sort=None),
#         x = alt.X("duration_start:Q", title= "Duration"),
#         x2 = "duration_end:Q",
#         color = 'Resource Name:N',
#         tooltip = ['Duration:Q', 'Data Transfered:Q','Error?:N']
#     )
#     text = bars.mark_text(
#         align='left',
#         baseline='middle',
#         color = 'black',
#         dx=-3  # Nudges text to right so it doesn't appear on top of the bar
#     ).encode(
#         color = 'Error?:N'
#         text='Error?:N'
#     )
#     return (bars + text).properties(height=300)

# %%
def plotTrace(traceID):
    source = traceDf[traceDf['Trace_ID'] == traceID]
    return alt.Chart(source, title='Trace: ' + traceID).mark_bar().encode(
        y=alt.Y('Resource Name', type='nominal', sort=None),
        x = alt.X("duration_start:Q", title= "Duration"),
        x2 = "duration_end:Q",
        color = 'Resource Name:N',
        tooltip = ['Duration:Q', 'Data Transfered:Q','Error?:N']
    )

# %%
def plotTraceTree(traceID):
    source = traceDf[traceDf['Trace_ID'] == traceID]
    return alt.Chart(source, title='Trace: ' + traceID).mark_bar().encode(
        y=alt.Y('Resource Name', type='nominal', sort=alt.SortField('order')),
        x = alt.X("loc start:Q", title= "Duration"),
        x2= "loc end:Q",
        color = 'Resource Name:N',
        tooltip = ['ID:N', 'Parent_ID:N', 'Duration:Q','Error?:N']
    )

# %%
plotTrace('ffea94949d425fe9')
# Out:
# alt.Chart(...)

# %%
plotTraceTree('ffea94949d425fe9')
# Out:
# alt.Chart(...)

# %%
plotTrace('b9ae10ad77e3ecee')
# Out:
# alt.Chart(...)

# %%
plotTraceTree('b9ae10ad77e3ecee')
# Out:
# alt.Chart(...)

# %%
plotTrace('106b33d6227a4e20')
# Out:
# alt.Chart(...)

# %%
plotTraceTree('106b33d6227a4e20')
# Out:
# alt.Chart(...)

# %% [markdown]
# AGGREGATE

# %%
rootTraces = traceDf[traceDf['Parent_ID'] == 'Na']
rootTraces
# Out:
#       Resource Name  Duration          Trace_ID                ID Parent_ID  \
# 17754         /cart    219000  05572cbb875880a0  05572cbb875880a0        Na
# 16819         /cart    219000  c2fe2262950dcfef  c2fe2262950dcfef        Na
# 18563         /cart    440000  7141eb616885e332  7141eb616885e332        Na
# 12930         /cart    416000  19e53a15d27bb0e8  19e53a15d27bb0e8        Na
# 17505         /cart    249000  e23a44e1cddedd2d  e23a44e1cddedd2d        Na
# ...             ...       ...               ...               ...       ...
# 5905          /cart    286000  cab3c0c5034022f3  cab3c0c5034022f3        Na
# 18223         /cart    207000  432b64aea6388eda  432b64aea6388eda        Na
# 7078          /cart    297000  8aafba8c1b40fe41  8aafba8c1b40fe41        Na
# 551           /cart    446000  64c1d9eec42bd573  64c1d9eec42bd573        Na
# 6457       /product    556000  57b4649cf7a54078  57b4649cf7a54078        Na
#
#       Error?  duration_start  duration_end  Data Transfered  order  loc start  \
# 17754  false           49000        268000           4864.6    0.0          0
# 16819  false           12000        231000           5981.9    0.0          0
# 18563  false          358000        798000           9898.1    0.0          0
# 12930  false               0        416000           2244.1    0.0          0
# 17505  false          226000        475000           9848.3    0.0          0
# ...      ...             ...           ...              ...    ...        ...
# 5905   false               0        286000           5897.1    0.0          0
# 18223  false          244000        451000           8238.8    0.0          0
# 7078   false               0        297000           4772.2    0.0          0
# 551    false          487000        933000           9884.4    0.0          0
# 6457   false          410000        966000           1556.3    0.0          0
#
#        loc end
# 17754   219000
# 16819   219000
# 18563   440000
# 12930   416000
# 17505   249000
# ...        ...
# 5905    286000
# 18223   207000
# 7078    297000
# 551     446000
# 6457    556000
#
# [4663 rows x 12 columns]

# %%
roots = list(set(rootTraces['Resource Name']))
roots
# Out:
# ['/product', '/checkout', '/currency', '/shipping', '/cart']

# %%
avgDurations = []
errorPercentage = []
aggregateTraceDf = pd.DataFrame()
for root in roots:
    print(root)
    traces = rootTraces[rootTraces['Resource Name'] == root]
    ids = list(set(traces['Trace_ID']))
    print(len(traces))
    traceDf['keep'] = [True if x in ids else False for x in traceDf['Trace_ID']]
    thisRootTraces = traceDf[traceDf['keep']]
    print(len(thisRootTraces))
    thisRootTraces['intErrors?'] = [1 if x =='true' else 0 for x in thisRootTraces['Error?']]
    grouped = thisRootTraces.groupby('Resource Name').agg({'Duration': ['mean'], 'intErrors?':['sum','count'], 'Data Transfered':['mean'], 'loc start': 'mean','loc end': 'mean', 'order':'mean' })
    grouped = grouped.reset_index()
    grouped['root'] = [root] * len(grouped)
    cols = []
    for x in grouped.columns:
        if x[1] =='mean':
            grouped[x] = round(grouped[x],2)
            cols.append('Average ' + x[0])
        elif x[1] != '':
            cols.append(x[1])
        else:
            cols.append(x[0])
    grouped.columns = cols
    grouped['Error Rate'] = round(grouped['sum']/grouped['count'],3)
    grouped = grouped.rename(columns = {'mean': 'Average Duration', 'count':'Error Count'})
    cols = ['root','Resource Name', 'Average Duration','Error Count','Error Rate','Average Data Transfered', 'Average loc start', 'Average loc end',
           'Average order']
    grouped = grouped[cols]
    grouped    
    aggregateTraceDf = aggregateTraceDf.append(grouped)
# Out:
# /product
# 728
# 3640
# /checkout
# 119
# 831
# /currency
# 51
# 153
# /shipping
# 121
# 363
# /cart
# 3644
# 14576

# %%
aggregateTraceDf
# Out:
#         root           Resource Name  Average Duration  Error Count  \
# 0   /product              /adrequest         246023.35          728
# 1   /product            /getproducts          54748.63         1456
# 2   /product     /getrecommendations         254630.49          728
# 3   /product                /product         527575.55          728
# 0  /checkout                /address          52000.01           87
# 1  /checkout               /checkout        1625361.34          119
# 2  /checkout         /creditcardinfo          25609.21           87
# 3  /checkout                /getcart          90103.45           87
# 4  /checkout          /getconversion         155471.26           87
# 5  /checkout                  /money          50620.69           87
# 6  /checkout            /orderresult          44577.46           71
# 7  /checkout             /placeorder         780773.11          119
# 8  /checkout  /sendorderconfirmation         484091.95           87
# 0  /currency               /currency         182078.43           51
# 1  /currency          /getconversion         136137.25           51
# 2  /currency                  /money          45588.24           51
# 0  /shipping                /address          49735.54          121
# 1  /shipping               /getquote         307272.73          121
# 2  /shipping               /shipping         352314.05          121
# 0      /cart                   /cart         360512.07         3644
# 1      /cart                /getcart         100416.85         3644
# 2      /cart            /getproducts          55692.11         3644
# 3      /cart     /getrecommendations         256827.11         3644
#
#    Error Rate  Average Data Transfered  Average loc start  Average loc end  \
# 0       0.000                  4830.63             100000        346023.35
# 1       0.000                  4975.35             150000        204748.63
# 2       0.000                  4973.73             100000        354630.49
# 3       0.000                  5212.94                  0        527575.55
# 0       0.000                  5130.73             200000        252000.01
# 1       0.403                  4490.52                  0       1625361.34
# 2       0.000                  4878.87             200000        225609.21
# 3       0.000                  4447.78             200000        290103.45
# 4       0.000                  4506.25             200000        355471.26
# 5       0.000                  4391.90             300000        350620.69
# 6       0.000                  5466.24             300000        344577.46
# 7       0.403                  5174.66             100000        880773.11
# 8       0.184                  4775.55             200000        684091.95
# 0       0.000                  5432.67                  0        182078.43
# 1       0.000                  5083.82             100000        236137.25
# 2       0.000                  4631.69             200000        245588.24
# 0       0.000                  5004.89             200000        249735.54
# 1       0.000                  4597.76             100000        407272.73
# 2       0.000                  4419.83                  0        352314.05
# 0       0.000                  5023.66                  0        360512.07
# 1       0.000                  4913.96             100000        200416.85
# 2       0.000                  4955.17             200000        255692.11
# 3       0.000                  4973.16             100000        356827.11
#
#    Average order
# 0           1.07
# 1           1.96
# 2           1.74
# 3           0.00
# 0           3.01
# 1           0.00
# 2           2.30
# 3           3.17
# 4           3.44
# 5           3.94
# 6           3.63
# 7           0.50
# 8           3.08
# 0           0.00
# 1           0.50
# 2           1.00
# 0           1.00
# 1           0.50
# 2           0.00
# 0           0.00
# 1           0.69
# 2           1.81
# 3           1.31

# %%
def plotTraceAgg(traceID):
    source = aggregateTraceDf[aggregateTraceDf['root'] == traceID]
    return alt.Chart(source, title='Trace Type: ' + traceID).mark_bar().encode(
        y=alt.Y('Resource Name', type='nominal', sort=alt.SortField('Average order')),
        x = alt.X("Average loc start:Q", title= "Duration"),
        x2 = "Average loc end:Q",
        color = 'Resource Name',
        tooltip = ['Average Duration:Q', 'Average Data Transfered:Q', 'Error Rate']
    )

# %%
plotTraceAgg('/checkout')
# Out:
# alt.Chart(...)
